# %%
#importing Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

#follow my github profile ManiShankar09 for more

# %%
#importing Data
df = pd.read_excel("C:\\Users\\manis\\OneDrive\\Documents\\covid states.xlsx") 
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar         9743     449        9165     129          4.61
# 1       Andhra Pradesh      2260181  115425     2130162   14594          5.11
# 2    Arunachal Pradesh        61953    3143       58524     286          5.07
# 3                Assam       713685   30135      677128    6422          4.22
# 4                Bihar       821815    7713      801885   12217          0.94
#
#    Discharge Ratio  Death Ratio  Population
# 0            94.07         1.32      399001
# 1            94.25         0.65    91702478
# 2            94.47         0.46     1711947
# 3            94.88         0.90    35998752
# 4            97.57         1.49   128500364

# %%
df.isnull().sum() #checking null Values
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %%
df.duplicated().sum() #checking Dulplicated values
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State/UTs        36 non-null     object
#  1   Total Cases      36 non-null     int64
#  2   Active           36 non-null     int64
#  3   Discharged       36 non-null     int64
#  4   Deaths           36 non-null     int64
#  5   Active Ratio     36 non-null     float64
#  6   Discharge Ratio  36 non-null     float64
#  7   Death Ratio      36 non-null     float64
#  8   Population       36 non-null     int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 2.7+ KB

# %%
df.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000     36.000000
# mean   1.141459e+06   52359.361111  1.075375e+06   13724.750000      4.496667
# std    1.683188e+06   81546.845285  1.585118e+06   25322.880783      2.252359
# min    9.743000e+03     117.000000  9.165000e+03       4.000000      0.940000
# 25%    9.773700e+04    3905.250000  9.223400e+04    1060.000000      2.895000
# 50%    5.709725e+05   24957.500000  5.456320e+05    5861.000000      4.265000
# 75%    1.202760e+06   51139.500000  1.125482e+06   14016.500000      5.832500
# max    7.683525e+06  336920.000000  7.292791e+06  142522.000000      9.860000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         94.373889     1.130833  3.971861e+07
# std           2.214921     0.485965  5.050913e+07
# min          89.060000     0.040000  6.600100e+04
# ...

# %%
df.shape #shows Shape of the dataset
# Out:
# (36, 9)

# %%
df.dtypes #shows column type
# Out:
# State/UTs           object
# Total Cases          int64
# Active               int64
# Discharged           int64
# Deaths               int64
# Active Ratio       float64
# Discharge Ratio    float64
# Death Ratio        float64
# Population           int64
# dtype: object

# %%
df.rename({'State/UTs' : 'State'},inplace = True)

# %%
df['State/UTs'].unique()
# Out:
# array(['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telengana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df['Total Cases'].max()
# Out:
# 7683525

# %%
A = (df['Total Cases'] > 7000000)
df.loc[A]
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 20  Maharashtra      7683525  248212     7292791  142522          3.23
#
#     Discharge Ratio  Death Ratio  Population
# 20            94.91         1.85   124904071

# %%
#Maharasta has highest Cases,Let see in Graph

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
sb.barplot(data=df,x='State/UTs',y='Total Cases')
# Out:
# <AxesSubplot:xlabel='State/UTs', ylabel='Total Cases'>

# %%
 #lets see Active cases

df['Active'].max()
# Out:
# 336920

# %%
B = (df['Active'] > 300000)
df.loc[B]                    ##Kerala has Highest active cases
# Out:
#    State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 16    Kerala      5931945  336920     5541834   53191          5.68
#
#     Discharge Ratio  Death Ratio  Population
# 16            93.42          0.9    34698876

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
sb.barplot(data=df,x='State/UTs',y='Population')
# Out:
# <AxesSubplot:xlabel='State/UTs', ylabel='Population'>

# %%
x = df['State/UTs']
y = df['Total Cases']
z = df['Active']
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.plot(x,y,z)

# %%
x = df['State/UTs']
y = df['Discharged']
z = df['Total Cases']
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.plot(x,y,z)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sb.scatterplot(data=df,x = 'Total Cases',y = 'Active')
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='Active'>

# %%
sb.scatterplot(data=df,x = 'Total Cases',y = 'Population')
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='Population'>

# %%
sb.pairplot(df)

# %%
g = sb.PairGrid(df)
g.map_upper(sb.histplot)
g.map_lower(sb.kdeplot,fill = True)
g.map_diag(sb.histplot,kde = True)

# %%
sb.displot(df,x='Total Cases',hue = 'State/UTs')

# %%
sb.lmplot(x = 'Discharged',y = 'Active',hue = 'State/UTs',data=df)

# %%
#top 6 states highest cases
C = (df['Total Cases'] > 2000000)

# %%
df.loc[C]
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1   Andhra Pradesh      2260181  115425     2130162   14594          5.11
# 15       Karnataka      3757031  252162     3465995   38874          6.71
# 16          Kerala      5931945  336920     5541834   53191          5.68
# 20     Maharashtra      7683525  248212     7292791  142522          3.23
# 30      Tamil Nadu      3303702  208350     3057846   37506          6.31
# 33   Uttar Pradesh      2005245   59601     1922480   23164          2.97
#
#     Discharge Ratio  Death Ratio  Population
# 1             94.25         0.65    91702478
# 15            92.25         1.03    69599762
# 16            93.42         0.90    34698876
# 20            94.91         1.85   124904071
# 30            92.56         1.14    83697770
# 33            95.87         1.16   231502578

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
sb.histplot(data=C,x=df['State/UTs'],y = df['Total Cases'])
# Out:
# <AxesSubplot:xlabel='State/UTs', ylabel='Total Cases'>

# %%
sb.relplot(x = df['Population'],y = df['Total Cases'],kind = 'line')
